# %%
import hana_ml.dataframe as dataframe
import pandas as pd

# %%
cc = dataframe.ConnectionContext(userkey = 'hana_ml_sl2044', encrypt = 'true', sslValidateCertificate = 'false')

# %%
# create the dataframe containing sales_document and material for any sale that contains a door (excluding components)
df_remote = cc.sql('SELECT SALES_DOCUMENT, MATERIAL \
                    FROM SALES_SC_LEVEL \
                    WHERE COMPONENT_FLAG <> 1 \
                    AND SALES_DOCUMENT IN (\
                        SELECT DISTINCT SALES_DOCUMENT \
                        FROM SALES_SC_LEVEL \
                        WHERE COMPONENT_FLAG <> 1 \
                        AND CATEGORY = \'D\' ) ')

# %%
# create a dictionary of material descriptions to help with a more meaningful
df_remote_desc = cc.table('MATERIAL_DESC')
desc_lookup = df_remote_desc.collect()[["MATERIAL","TXTMD"]].set_index('MATERIAL').T.to_dict('records')[0]

# %%
# show the top 3 items in our source dataset
df_remote.head(3).collect()
# Out:
#   SALES_DOCUMENT MATERIAL
# 0     F150118160  LAL0130
# 1     E260199614  SNK2143
# 2     F270075868  LAL1211

# %%
# perform a statistical analysis of the data
df_remote.describe().collect()
# Out:
#            column    count   unique  nulls  mean   std   min   max median  \
# 0  SALES_DOCUMENT  4010599  1074022      0  None  None  None  None   None
# 1        MATERIAL  4010599    39765      0  None  None  None  None   None
#
#   25_percent_cont 25_percent_disc 50_percent_cont 50_percent_disc  \
# 0            None            None            None            None
# 1            None            None            None            None
#
#   75_percent_cont 75_percent_disc
# 0            None            None
# 1            None            None

# %% [markdown]
# ### DEFINITION
#
# Association rules analysis is a technique to uncover how items are associated to each other. There are three common ways to measure association.
#
# **Measure 1: Support.** This says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears. In Table 1 below, the support of {apple} is 4 out of 8, or 50%. Itemsets can also contain multiple items. For instance, the support of {apple, beer, rice} is 2 out of 8, or 25%.
#
# <div style='text-align: center'>
#     <img src='association-rule-support-eqn.png' alt="Association Rule Support eqn" width="165" height="45">
# </div>
#
#
# <div style='text-align: center'>
#     <img src='association-rule-support-table.png' alt="association-rule-support-table" width="326" height="289">
#     <p style='text-align: center'>Table 1. Example Transactions</p>
# </div>
#
# If you discover that sales of items beyond a certain proportion tend to have a significant impact on your profits, you might consider using that proportion as your support threshold. You may then identify itemsets with support values above this threshold as significant itemsets.
#
# **Measure 2: Confidence.** This says how likely item Y is purchased when item X is purchased, expressed as {X -> Y}. This is measured by the proportion of transactions with item X, in which item Y also appears. In Table 1, the confidence of {apple -> beer} is 3 out of 4, or 75%.
#
# <div style='text-align: center'>
#     <img src='association-rule-confidence-eqn.png' alt="Association Rule Confidence eqn" width="351" height="51">
# </div>
#
# One drawback of the confidence measure is that it might misrepresent the importance of an association. This is because it only accounts for how popular apples are, but not beers. If beers are also very popular in general, there will be a higher chance that a transaction containing apples will also contain beers, thus inflating the confidence measure. To account for the base popularity of both constituent items, we use a third measure called lift.
#
# **Measure 3: Lift.** This says how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. In Table 1, the lift of {apple -> beer} is 1, which implies no association between items. A lift value greater than 1 means that item Y is likely to be bought if item X is bought, while a value less than 1 means that item Y is unlikely to be bought if item X is bought.
#
# <div style='text-align: center'>
#     <img src='association-rule-lift-eqn.png' alt="Association Rule Lift eqn" width="377" height="52">
# </div>

# %%
# use the Apriori algorithm
from hana_ml.algorithms.pal.association import Apriori

# %%
# set up the association model
ap = Apriori( min_support= 0.0001,
              min_confidence=0.5,
              relational=False,
              min_lift=1,
              max_conseq=1,
              max_len=5,
              ubiquitous=1.0,
              use_prefix_tree=False,
              thread_ratio=0,
              timeout=3600,
              pmml_export='single-row')

# %%
# run the model on the dataset
ap.fit(data=df_remote)

# %%
# collect the results into a dataframe for manipulation
df_result = ap.result_.collect()

# %%
# top 10 results by confidence (the likelihood of this happening based on the number of transactions)
# The antecedent is the list of items in the basket that appear before (or predict) the consequent item
df_result.sort_values(by=['CONFIDENCE'], ascending=False).head(10)
# Out:
#                    ANTECEDENT CONSEQUENT   SUPPORT  CONFIDENCE         LIFT
# 6049  KIT0007&KIT0006&KSC0102    KIT0001  0.000262         1.0  2926.490463
# 4570  HKB1188&TAP3303&HYH8400    GIR0119  0.000101         1.0   320.030393
# 4566  HKB1188&RKC0156&HYH8400    GIR0119  0.000102         1.0   320.030393
# 499                   KSC0112    KSC0102  0.000205         1.0  3356.318750
# 4562  HKB1188&RKC0156&TAP3303    GIR0119  0.000103         1.0   320.030393
# 497                   KSC0110    KSC0102  0.000237         1.0  3356.318750
# 493                   KSC0110    KSC0114  0.000237         1.0  3509.875817
# 3876          SRA0005&NWL0037    SRA0004  0.000122         1.0  1245.965197
# 489                   KSC0112    KIT0006  0.000205         1.0  2942.526027
# 487                   KSC0110    KIT0006  0.000237         1.0  2942.526027

# %%
# top 10 results by confidence (the likelihood of this happening based on the antecedent occurring to the same consequent)
df_result.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                    ANTECEDENT CONSEQUENT   SUPPORT  CONFIDENCE         LIFT
# 3382          WHT4160&GNO2420    GNO2129  0.000120    0.934783  6519.331733
# 3303          SNK5176&GNO2129    GNO2420  0.000103    0.840909  6497.517005
# 5781  SNK5176&WHT4160&GNO2129    GNO2420  0.000103    0.840909  6497.517005
# 5789  WHT4160&GNO2920&GNO2129    GNO2420  0.000102    0.839695  6488.133341
# 3410          GNO2920&GNO2129    GNO2420  0.000102    0.839695  6488.133341
# 3383          WHT4160&GNO2129    GNO2420  0.000120    0.837662  6472.430066
# 126                   GNO2129    GNO2420  0.000120    0.837662  6472.430066
# 125                   GNO2420    GNO2129  0.000120    0.928058  6472.430066
# 3302          SNK5176&GNO2420    GNO2129  0.000103    0.925000  6451.106169
# 5780  SNK5176&WHT4160&GNO2420    GNO2129  0.000103    0.925000  6451.106169

# %%
# split the antecedent into columns to enable us to show the SKU description for analysis
df_result = df_result.join( df_result['ANTECEDENT'].str.split('&',expand=True).rename(columns={0:'ANTECEDENT_1', 1:'ANTECEDENT_2', 2:'ANTECEDENT_3', 3:'ANTECEDENT_4', 4:'ANTECEDENT_5'} ) )
df_result.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                    ANTECEDENT CONSEQUENT   SUPPORT  CONFIDENCE         LIFT  \
# 3382          WHT4160&GNO2420    GNO2129  0.000120    0.934783  6519.331733
# 3303          SNK5176&GNO2129    GNO2420  0.000103    0.840909  6497.517005
# 5781  SNK5176&WHT4160&GNO2129    GNO2420  0.000103    0.840909  6497.517005
# 5789  WHT4160&GNO2920&GNO2129    GNO2420  0.000102    0.839695  6488.133341
# 3410          GNO2920&GNO2129    GNO2420  0.000102    0.839695  6488.133341
# 3383          WHT4160&GNO2129    GNO2420  0.000120    0.837662  6472.430066
# 126                   GNO2129    GNO2420  0.000120    0.837662  6472.430066
# 125                   GNO2420    GNO2129  0.000120    0.928058  6472.430066
# 3302          SNK5176&GNO2420    GNO2129  0.000103    0.925000  6451.106169
# 5780  SNK5176&WHT4160&GNO2420    GNO2129  0.000103    0.925000  6451.106169
#
#      ANTECEDENT_1 ANTECEDENT_2 ANTECEDENT_3 ANTECEDENT_4
# 3382      WHT4160      GNO2420         None         None
# 3303      SNK5176      GNO2129         None         None
# 5781      SNK5176      WHT4160      GNO2129         None
# 5789      WHT4160      GNO2920      GNO2129         None
# 3410      GNO2920      GNO2129         None         None
# 3383      WHT4160      GNO2129         None         None
# 126       GNO2129         None         None         None
# 125       GNO2420         None         None         None
# 3302      SNK5176      GNO2420         None         None
# 5780      SNK5176      WHT4160      GNO2420         None

# %%
df_basket_analysis = dataframe.create_dataframe_from_pandas(cc, df_result, 'Basket_Analysis_2019', force=True, replace=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]

# %%
df_result.to_csv('df_basket_analysis.csv', index=False)

# %%
# add sku descriptions to items to make it more readable
df_result['CONSEQUENT_DESC'] = df_result['CONSEQUENT'].map(desc_lookup).fillna(df_result['CONSEQUENT'])
df_result['ANTECEDENT_1_DESC'] = df_result['ANTECEDENT_1'].map(desc_lookup).fillna(df_result['ANTECEDENT_1'])
df_result['ANTECEDENT_2_DESC'] = df_result['ANTECEDENT_2'].map(desc_lookup).fillna(df_result['ANTECEDENT_2'])
df_result['ANTECEDENT_3_DESC'] = df_result['ANTECEDENT_3'].map(desc_lookup).fillna(df_result['ANTECEDENT_3'])
df_result['ANTECEDENT_4_DESC'] = df_result['ANTECEDENT_4'].map(desc_lookup).fillna(df_result['ANTECEDENT_4'])
#df_result['ANTECEDENT_5_DESC'] = df_result['ANTECEDENT_5'].map(desc_lookup).fillna(df_result['ANTECEDENT_5'])

# create a new dataframe of the result using sku descriptions
df_result_desc = df_result[['ANTECEDENT_1_DESC','ANTECEDENT_2_DESC','ANTECEDENT_3_DESC','ANTECEDENT_4_DESC','CONSEQUENT_DESC','SUPPORT','CONFIDENCE','LIFT']]

# %%
df_result_desc.to_csv('df_basket_analysis_desc.csv', index=False)

# %%
# show the result (ordered by lift) using SKU descriptions
df_result_desc.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                             ANTECEDENT_1_DESC  \
# 3277  Blk Gran Effect 3m 600 38 8mm rad W/top
# 5785  Blk Gran Effect 3m 600 38 8mm rad W/top
# 3405               Gno Lo 170D 500 4 Dwr Base
# 3402               Gno Lo 170D 500 4 Dwr Base
# 5781  Blk Gran Effect 3m 600 38 8mm rad W/top
# 3278  Blk Gran Effect 3m 600 38 8mm rad W/top
# 112                Gno Lo 170D 500 4 Dwr Base
# 111           Gno Lo Nh 170D 500 Full Ht Wall
# 3404          Gno Lo Nh 170D 500 Full Ht Wall
# 5784  Blk Gran Effect 3m 600 38 8mm rad W/top
#
#                     ANTECEDENT_2_DESC           ANTECEDENT_3_DESC  \
# 3277  Gno Lo Nh 170D 500 Full Ht Wall                        None
# 5785       Gno Lo 170D 500 4 Dwr Base  Drayton 1.5 bowl inc waste
# 3405       Drayton 1.5 bowl inc waste                        None
# 3402            Gno Continuous Plinth                        None
# 5781       Gno Lo 170D 500 4 Dwr Base       Gno Continuous Plinth
# 3278       Gno Lo 170D 500 4 Dwr Base                        None
# 112                              None                        None
# 111                              None                        None
# 3404       Drayton 1.5 bowl inc waste                        None
# 5784  Gno Lo Nh 170D 500 Full Ht Wall  Drayton 1.5 bowl inc waste
#
#      ANTECEDENT_4_DESC                  CONSEQUENT_DESC   SUPPORT  CONFIDENCE  \
# 3277              None       Gno Lo 170D 500 4 Dwr Base  0.000120    0.934783
# 5785              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000103    0.840909
# 3405              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000103    0.840909
# 3402              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000102    0.839695
# 5781              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000102    0.839695
# 3278              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000120    0.837662
# 112               None  Gno Lo Nh 170D 500 Full Ht Wall  0.000120    0.837662
# 111               None       Gno Lo 170D 500 4 Dwr Base  0.000120    0.928058
# 3404              None       Gno Lo 170D 500 4 Dwr Base  0.000103    0.925000
# 5784              None       Gno Lo 170D 500 4 Dwr Base  0.000103    0.925000
#
#              LIFT
# 3277  6519.331733
# 5785  6497.517005
# 3405  6497.517005
# 3402  6488.133341
# 5781  6488.133341
# 3278  6472.430066
# 112   6472.430066
# 111   6472.430066
# 3404  6451.106169
# 5784  6451.106169

# %%
# show the result (ordered by confidence) using SKU descriptions
df_result_desc.sort_values(by=['CONFIDENCE'], ascending=False).head(10)
# Out:
#                             ANTECEDENT_1_DESC  \
# 6173  88x2070x25 Kit Std Primed-Wh Hinges-826
# 5695           NP Tubular econ 2.5 mort.latch
# 5787               Gno Lo 170D 500 4 Dwr Base
# 6230          Stainless Steel Effect D Handle
# 6090                826 6PG Bath Doorkit Leaf
# 4555          Stainless Steel Effect D Handle
# 4151                826 6PG Bath Doorkit Leaf
# 4150  88x2070x25 Kit Bath Primed-Wh Hnges-826
# 5789  Blk Gran Effect 3m 600 38 8mm rad W/top
# 5790  Blk Gran Effect 3m 600 38 8mm rad W/top
#
#                              ANTECEDENT_2_DESC  \
# 6173   88x2070x25 Kit Std Primed-Wh Hinges-626
# 5695   Blk Gran Effect 3m 600 38 8mm rad W/top
# 5787                        Black 38mm End Cap
# 6230   Blk Gran Effect 3m 600 38 8mm rad W/top
# 6090   88x2070x25 Kit Std Primed-Wh Hinges-826
# 4555   Blk Gran Effect 3m 600 38 8mm rad W/top
# 4151  125x2070x25 Kit Std Primed-Wh Hinges-826
# 4150  125x2070x25 Kit Std Primed-Wh Hinges-826
# 5789                Gno Lo 170D 500 4 Dwr Base
# 5790                Gno Lo 170D 500 4 Dwr Base
#
#                              ANTECEDENT_3_DESC  \
# 6173  125x2070x25 Kit Std Primed-Wh Hinges-826
# 5695                Drayton 1.5 bowl inc waste
# 5787            Light Oak plinth corner strips
# 6230                 HD Leg Plinth Return Pack
# 6090   88x2070x25 Kit Std Primed-Wh Hinges-626
# 4555         Lamona Chrome Effect Monobloc Tap
# 4151                                      None
# 4150                                      None
# 5789            Light Oak plinth corner strips
# 5790                        Black 38mm End Cap
#
#                       ANTECEDENT_4_DESC  \
# 6173                               None
# 5695                               None
# 5787                               None
# 6230  Lamona Chrome Effect Monobloc Tap
# 6090                               None
# 4555                               None
# 4151                               None
# 4150                               None
# 5789                               None
# 5790                               None
#
#                               CONSEQUENT_DESC   SUPPORT  CONFIDENCE  \
# 6173                 826 6PG Std Doorkit Leaf  0.000154         1.0
# 5695          S/S Effect T Bar Handle - 230mm  0.000106         1.0
# 5787  Blk Gran Effect 3m 600 38 8mm rad W/top  0.000103         1.0
# 6230                       Black 38mm End Cap  0.000102         1.0
# 6090                 826 6PG Std Doorkit Leaf  0.000237         1.0
# 4555                       Black 38mm End Cap  0.000103         1.0
# 4151  88x2070x25 Kit Bath Primed-Wh Hnges-826  0.000205         1.0
# 4150                826 6PG Bath Doorkit Leaf  0.000205         1.0
# 5789                       Black 38mm End Cap  0.000103         1.0
# 5790           Light Oak plinth corner strips  0.000103         1.0
#
#              LIFT
# 6173  2942.526027
# 5695   169.725348
# 5787   212.299269
# 6230   320.030393
# 6090  2942.526027
# 4555   320.030393
# 4151  3356.318750
# 4150  2926.490463
# 5789   320.030393
# 5790  3051.198864

# %%
from hana_ml.algorithms.pal.association import FPGrowth

# %%
fpg = FPGrowth(
                   min_support=0.0001,
                   min_confidence=0.5,
                   relational=False,
                   min_lift=1.0,
                   max_conseq=1,
                   max_len=5,
                   ubiquitous=1.0,
                   thread_ratio=0,
                   timeout=3600)

# %%
fpg.fit(data=df_remote)

# %%
df_fpg_result = fpg.result_.collect()
df_fpg_result.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                             ANTECEDENT CONSEQUENT   SUPPORT  CONFIDENCE  \
# 29537  HNG0025&DCL0007&DCL0007&SCF0009    GIR0038  0.013218        14.0
# 28963  HNG0025&DXE0001&DXE0001&LAL0505    GIR0038  0.015421        14.0
# 30422  HNG0025&LAL0230&LAL0230&DFU0205    GIR0038  0.015056        14.0
# 29121  HNG0025&DXE0001&DCL0007&DFU0205    GIR0038  0.026096        14.0
# 29156  HNG0025&DXE0001&SCF0009&SCF0009    GIR0038  0.014234        14.0
# 29275  HNG0025&DXE0001&DFR0111&LAL0505    GIR0038  0.030841        14.0
# 29295  HNG0025&DXE0001&DFR0111&DFU0205    GIR0038  0.026096        14.0
# 29337  HNG0025&DXE0001&LAL0505&LAL0505    GIR0038  0.014234        14.0
# 29372  HNG0025&DXE0001&LAL0230&LAL0230    GIR0038  0.019162        14.0
# 29606  HNG0025&DCL0007&DCL0007&DFU0205    GIR0038  0.011184        14.0
#
#                LIFT
# 29537  51318.457338
# 28963  51318.457338
# 30422  51318.457338
# 29121  51318.457338
# 29156  51318.457338
# 29275  51318.457338
# 29295  51318.457338
# 29337  51318.457338
# 29372  51318.457338
# 29606  51318.457338

# %%
df_fpg_result = df_fpg_result.join( df_fpg_result['ANTECEDENT'].str.split('&',expand=True).rename(columns={0:'ANTECEDENT_1', 1:'ANTECEDENT_2', 2:'ANTECEDENT_3', 3:'ANTECEDENT_4', 4:'ANTECEDENT_5'} ) )
df_fpg_result.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                             ANTECEDENT CONSEQUENT   SUPPORT  CONFIDENCE  \
# 29537  HNG0025&DCL0007&DCL0007&SCF0009    GIR0038  0.013218        14.0
# 28963  HNG0025&DXE0001&DXE0001&LAL0505    GIR0038  0.015421        14.0
# 30422  HNG0025&LAL0230&LAL0230&DFU0205    GIR0038  0.015056        14.0
# 29121  HNG0025&DXE0001&DCL0007&DFU0205    GIR0038  0.026096        14.0
# 29156  HNG0025&DXE0001&SCF0009&SCF0009    GIR0038  0.014234        14.0
# 29275  HNG0025&DXE0001&DFR0111&LAL0505    GIR0038  0.030841        14.0
# 29295  HNG0025&DXE0001&DFR0111&DFU0205    GIR0038  0.026096        14.0
# 29337  HNG0025&DXE0001&LAL0505&LAL0505    GIR0038  0.014234        14.0
# 29372  HNG0025&DXE0001&LAL0230&LAL0230    GIR0038  0.019162        14.0
# 29606  HNG0025&DCL0007&DCL0007&DFU0205    GIR0038  0.011184        14.0
#
#                LIFT ANTECEDENT_1 ANTECEDENT_2 ANTECEDENT_3 ANTECEDENT_4
# 29537  51318.457338      HNG0025      DCL0007      DCL0007      SCF0009
# 28963  51318.457338      HNG0025      DXE0001      DXE0001      LAL0505
# 30422  51318.457338      HNG0025      LAL0230      LAL0230      DFU0205
# 29121  51318.457338      HNG0025      DXE0001      DCL0007      DFU0205
# 29156  51318.457338      HNG0025      DXE0001      SCF0009      SCF0009
# 29275  51318.457338      HNG0025      DXE0001      DFR0111      LAL0505
# 29295  51318.457338      HNG0025      DXE0001      DFR0111      DFU0205
# 29337  51318.457338      HNG0025      DXE0001      LAL0505      LAL0505
# 29372  51318.457338      HNG0025      DXE0001      LAL0230      LAL0230
# 29606  51318.457338      HNG0025      DCL0007      DCL0007      DFU0205

# %%
df_fpg_result['CONSEQUENT_DESC'] = df_fpg_result['CONSEQUENT'].map(desc_lookup).fillna(df_fpg_result['CONSEQUENT'])
df_fpg_result['ANTECEDENT_1_DESC'] = df_fpg_result['ANTECEDENT_1'].map(desc_lookup).fillna(df_fpg_result['ANTECEDENT_1'])
df_fpg_result['ANTECEDENT_2_DESC'] = df_fpg_result['ANTECEDENT_2'].map(desc_lookup).fillna(df_fpg_result['ANTECEDENT_2'])
df_fpg_result['ANTECEDENT_3_DESC'] = df_fpg_result['ANTECEDENT_3'].map(desc_lookup).fillna(df_fpg_result['ANTECEDENT_3'])
df_fpg_result['ANTECEDENT_4_DESC'] = df_fpg_result['ANTECEDENT_4'].map(desc_lookup).fillna(df_fpg_result['ANTECEDENT_4'])

df_fpg_result_desc = df_fpg_result[['ANTECEDENT_1_DESC','ANTECEDENT_2_DESC','ANTECEDENT_3_DESC','ANTECEDENT_4_DESC','CONSEQUENT_DESC','SUPPORT','CONFIDENCE','LIFT']]

# %%
df_fpg_result_desc.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                         ANTECEDENT_1_DESC  \
# 29537  4" SSS Ball Bearing Hinge Grade 11
# 28963  4" SSS Ball Bearing Hinge Grade 11
# 30422  4" SSS Ball Bearing Hinge Grade 11
# 29121  4" SSS Ball Bearing Hinge Grade 11
# 29156  4" SSS Ball Bearing Hinge Grade 11
# 29275  4" SSS Ball Bearing Hinge Grade 11
# 29295  4" SSS Ball Bearing Hinge Grade 11
# 29337  4" SSS Ball Bearing Hinge Grade 11
# 29372  4" SSS Ball Bearing Hinge Grade 11
# 29606  4" SSS Ball Bearing Hinge Grade 11
#
#                          ANTECEDENT_2_DESC  \
# 29537         Silver briton 2003 dr closer
# 28963                 Hardwood weather bar
# 30422  Euro/oval cyl deadlck case 3" satin
# 29121                 Hardwood weather bar
# 29156                 Hardwood weather bar
# 29275                 Hardwood weather bar
# 29295                 Hardwood weather bar
# 29337                 Hardwood weather bar
# 29372                 Hardwood weather bar
# 29606         Silver briton 2003 dr closer
#
#                          ANTECEDENT_3_DESC  \
# 29537         Silver briton 2003 dr closer
# 28963                 Hardwood weather bar
# 30422  Euro/oval cyl deadlck case 3" satin
# 29121         Silver briton 2003 dr closer
# 29156               Era chrome door viewer
# 29275    2'6 Unass FD30 No sill Ex Door Fr
# 29295    2'6 Unass FD30 No sill Ex Door Fr
# 29337  Nightlatch yale 89 gry case brs cyl
# 29372  Euro/oval cyl deadlck case 3" satin
# 29606         Silver briton 2003 dr closer
#
#                          ANTECEDENT_4_DESC           CONSEQUENT_DESC  \
# 29537               Era chrome door viewer  933mm Aluminium Threshex
# 28963  Nightlatch yale 89 gry case brs cyl  933mm Aluminium Threshex
# 30422        Vict'n c/plated cylinder pull  933mm Aluminium Threshex
# 29121        Vict'n c/plated cylinder pull  933mm Aluminium Threshex
# 29156               Era chrome door viewer  933mm Aluminium Threshex
# 29275  Nightlatch yale 89 gry case brs cyl  933mm Aluminium Threshex
# 29295        Vict'n c/plated cylinder pull  933mm Aluminium Threshex
# 29337  Nightlatch yale 89 gry case brs cyl  933mm Aluminium Threshex
# 29372  Euro/oval cyl deadlck case 3" satin  933mm Aluminium Threshex
# 29606        Vict'n c/plated cylinder pull  933mm Aluminium Threshex
#
#         SUPPORT  CONFIDENCE          LIFT
# 29537  0.013218        14.0  51318.457338
# 28963  0.015421        14.0  51318.457338
# 30422  0.015056        14.0  51318.457338
# 29121  0.026096        14.0  51318.457338
# 29156  0.014234        14.0  51318.457338
# 29275  0.030841        14.0  51318.457338
# 29295  0.026096        14.0  51318.457338
# 29337  0.014234        14.0  51318.457338
# 29372  0.019162        14.0  51318.457338
# 29606  0.011184        14.0  51318.457338

# %%
df_result_desc.sort_values(by=['LIFT'], ascending=False).head(10)
# Out:
#                             ANTECEDENT_1_DESC  \
# 3277  Blk Gran Effect 3m 600 38 8mm rad W/top
# 5785  Blk Gran Effect 3m 600 38 8mm rad W/top
# 3405               Gno Lo 170D 500 4 Dwr Base
# 3402               Gno Lo 170D 500 4 Dwr Base
# 5781  Blk Gran Effect 3m 600 38 8mm rad W/top
# 3278  Blk Gran Effect 3m 600 38 8mm rad W/top
# 112                Gno Lo 170D 500 4 Dwr Base
# 111           Gno Lo Nh 170D 500 Full Ht Wall
# 3404          Gno Lo Nh 170D 500 Full Ht Wall
# 5784  Blk Gran Effect 3m 600 38 8mm rad W/top
#
#                     ANTECEDENT_2_DESC           ANTECEDENT_3_DESC  \
# 3277  Gno Lo Nh 170D 500 Full Ht Wall                        None
# 5785       Gno Lo 170D 500 4 Dwr Base  Drayton 1.5 bowl inc waste
# 3405       Drayton 1.5 bowl inc waste                        None
# 3402            Gno Continuous Plinth                        None
# 5781       Gno Lo 170D 500 4 Dwr Base       Gno Continuous Plinth
# 3278       Gno Lo 170D 500 4 Dwr Base                        None
# 112                              None                        None
# 111                              None                        None
# 3404       Drayton 1.5 bowl inc waste                        None
# 5784  Gno Lo Nh 170D 500 Full Ht Wall  Drayton 1.5 bowl inc waste
#
#      ANTECEDENT_4_DESC                  CONSEQUENT_DESC   SUPPORT  CONFIDENCE  \
# 3277              None       Gno Lo 170D 500 4 Dwr Base  0.000120    0.934783
# 5785              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000103    0.840909
# 3405              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000103    0.840909
# 3402              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000102    0.839695
# 5781              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000102    0.839695
# 3278              None  Gno Lo Nh 170D 500 Full Ht Wall  0.000120    0.837662
# 112               None  Gno Lo Nh 170D 500 Full Ht Wall  0.000120    0.837662
# 111               None       Gno Lo 170D 500 4 Dwr Base  0.000120    0.928058
# 3404              None       Gno Lo 170D 500 4 Dwr Base  0.000103    0.925000
# 5784              None       Gno Lo 170D 500 4 Dwr Base  0.000103    0.925000
#
#              LIFT
# 3277  6519.331733
# 5785  6497.517005
# 3405  6497.517005
# 3402  6488.133341
# 5781  6488.133341
# 3278  6472.430066
# 112   6472.430066
# 111   6472.430066
# 3404  6451.106169
# 5784  6451.106169

# %%
#from hana_ml.algorithms.pal.association import KORD

# %%
#krd =  KORD(k=50,measure='lift',min_support=0.001,min_confidence=0.5,epsilon=0.1,use_epsilon=False)

# %%
#krd.fit(data=df_remote, transaction='SALES_DOCUMENT' , item='MATERIAL')
#krd.result_.head(5).collect()
